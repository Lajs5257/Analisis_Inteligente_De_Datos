# %% [markdown]
# <a href="https://colab.research.google.com/github/Lajs5257/Analisis_Inteligente_De_Datos/blob/main/Analisis_Datos_Peliculas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisis Datos Peliculas
# ## Luis Alberto Jimenez Soto
# 2022-08-31

# %% [markdown]
# # Objetivo
#
# Explorar datos de un archivo csv por medio de librería pandas

# %% [markdown]
# # Descripción
# Identificar una ruta WEB en donde se encuentra un archivo csv que contenga varias variables cpn lo cual se podrá importar con la función de read (lectura) que permitirá explorar sus datos.

# %% [markdown]
# # Marco teórico
#
# La exploración de datos es un primer paso del análisis de datos que se utiliza para explorar y visualizar datos para descubrir conocimientos desde el mismo inicio o identificar áreas o patrones para profundizarlos más. [texto del vínculo](https://www.tibco.com/es/reference-center/what-is-data-exploration#:~:text=La%20exploraci%C3%B3n%20de%20datos%20es,o%20patrones%20para%20profundizarlos%20m%C3%A1s.)

# %% [markdown]
# # Desarrollo
# Va a contener varios elementos:
#
# * Cargar librerías
# * Cargar datos
# * Explorar datos
# * Visualizar datos

# %% [markdown]
# ## Cargar librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar datos
#
# Los datos se encuentran en la URL: [https://raw.githubusercontent.com/rpizarrog/Analisis-Inteligente-de-datos/main/datos/movies-db.csv](https://raw.githubusercontent.com/rpizarrog/Analisis-Inteligente-de-datos/main/datos/movies-db.csv)

# %%
datos = pd.read_csv("https://raw.githubusercontent.com/rpizarrog/Analisis-Inteligente-de-datos/main/datos/movies-db.csv")
datos
# Out:
#                                          name  year  length_min      genre  \
# 0                                   Toy Story  1995          81  Animation
# 1                                       Akira  1998         125  Animation
# 2                          The Breakfast Club  1985          97      Drama
# 3                                  The Artist  2011         100    Romance
# 4                                Modern Times  1936          87     Comedy
# 5                                  Fight Club  1999         139      Drama
# 6                                 City of God  2002         130      Crime
# 7                            The Untouchables  1987         119      Drama
# 8                        Star Wars Episode IV  1977         121     Action
# 9                             American Beauty  1999         122      Drama
# 10                                       Room  2015         118      Drama
# ...

# %% [markdown]
# ## Explorar datos

# %% [markdown]
# ### head()
#
# Explorar los primeros registros con función head()

# %%
datos.head(10)
# Out:
#                    name  year  length_min      genre  average_rating  \
# 0             Toy Story  1995          81  Animation             8.3
# 1                 Akira  1998         125  Animation             8.1
# 2    The Breakfast Club  1985          97      Drama             7.9
# 3            The Artist  2011         100    Romance             8.0
# 4          Modern Times  1936          87     Comedy             8.6
# 5            Fight Club  1999         139      Drama             8.9
# 6           City of God  2002         130      Crime             8.7
# 7      The Untouchables  1987         119      Drama             7.9
# 8  Star Wars Episode IV  1977         121     Action             8.7
# 9       American Beauty  1999         122      Drama             8.4
#
#    cost_millions  foreign  age_restriction
# 0           30.0        0                0
# 1           10.4        1               14
# 2            1.0        0               14
# ...

# %% [markdown]
# ### tail()
#  Explorar los últimos registros

# %%
datos.tail(10)
# Out:
#                                          name  year  length_min     genre  \
# 21                 Blue is the Warmest Colour  2013         179   Romance
# 22                                 Black Swan  2010         108  Thriller
# 23                         Back to the Future  1985         116    Sci-fi
# 24                                   The Wave  2008         107  Thriller
# 25                                   Whiplash  2014         106     Drama
# 26                   The Grand Hotel Budapest  2014         100     Crime
# 27                                    Jumanji  1995         104   Fantasy
# 28  The Eternal Sunshine of the Spotless Mind  2004         108     Drama
# 29                                    Chicago  2002         113    Comedy
# 30                                    Jumangi  2020         120    Action
#
#     average_rating  cost_millions  foreign  age_restriction
# 21             7.8            4.5        1               18
# ...

# %% [markdown]
# ### Tipo de dato
#
# Se identifica el tipo de datos que tiene la variable datos siendo un data.frame y cada variable de datos.

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.dtypes
# Out:
# name                object
# year                 int64
# length_min           int64
# genre               object
# average_rating     float64
# cost_millions      float64
# foreign              int64
# age_restriction      int64
# dtype: object

# %% [markdown]
# ### Decripción de los datos
#
# Se presenta valores estadístcos de los datos del archivo importado

# %%
datos.describe()
# Out:
#               year  length_min  average_rating  cost_millions    foreign  \
# count    31.000000   31.000000       31.000000      31.000000  31.000000
# mean   1996.290323  116.903226        8.100000      23.193548   0.387097
# std      17.586346   24.888223        0.734847      32.201531   0.495138
# min    1936.000000   81.000000        5.200000       0.400000   0.000000
# 25%    1988.500000   99.500000        7.950000       3.750000   0.000000
# 50%    1999.000000  113.000000        8.300000      13.000000   0.000000
# 75%    2009.000000  123.500000        8.500000      25.250000   1.000000
# max    2020.000000  179.000000        9.300000     165.000000   1.000000
#
#        age_restriction
# count        31.000000
# mean         12.903226
# std           5.028948
# min           0.000000
# 25%          12.000000
# 50%          14.000000
# 75%          16.000000
# max          18.000000

# %% [markdown]
# ### Estadísticos de variable de interés
#
# La variable de estudio es el rating de las películas

# %%
print("average_rating")
print("Valor mínimo:", datos['average_rating'].min())
print("Valor máximo:",datos['average_rating'].max())
print("La media aritmética:",datos['average_rating'].mean())
print("Desviación Estándar:",datos['average_rating'].std())
print("Núm. de observaciones:",datos['average_rating'].count())
# Out:
# average_rating
# Valor mínimo: 5.2
# Valor máximo: 9.3
# La media aritmética: 8.1
# Desviación Estándar: 0.7348469228349533
# Núm. de observaciones: 31

# %% [markdown]
# ### Visualizar datos
#
# La variable de interés es el idioma (foreign). Se determina la frecuencia.

# %%
ceros = datos['foreign'] == 0
print(ceros.value_counts())


frecuencia = (datos.groupby("foreign").agg(frequency=("foreign", "count")))
frecuencia
# Out:
# True     19
# False    12
# Name: foreign, dtype: int64
#          frequency
# foreign
# 0               19
# 1               12

# %%
datos.groupby('foreign').count()['name'].plot(kind='bar')

# %% [markdown]
# La variable de interés es el género (genre). Se determina la frecuencia.

# %%
datos.groupby('genre').count()['name'].plot(kind='bar')

# %% [markdown]
# # Interpretación
#
# El conjunto de datos contiene observaciones relacionadas con características de películas, el *data.frame* de datos tiene 31 observaciones y diez variables.
#
# Existe 19 películas en idioma inglés y 12 en idioma extranjero diferente al inglés.
#
# Con respecto a la variable género de película, el género que más existe es el de drama con siete observaciones y el que menos predomina es el de aventura y ciencia ficción con uno respectiamente.
#
# Los estadísticos descriptivos arrojan que el valor medio de minutos de todas las películas es de 116.90 minutos, el valor medio del costo de las películas es de 23.193548.
#
# Es interesante como con el analisis de estos datos podemos determinar ciertas conclusiones en base a esto, el como se tiene una gran popularidad las peliculas de drama y comedia, como podemos ver que ambas tienen una buena aceptación por el publico, con esto se favorece el que se sigan creando más de estas peliculas que son bien recibidas por el publico
